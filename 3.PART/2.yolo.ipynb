# %% [markdown]
# # YOLO
# pip install ultralytics

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\yx084\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")

# %%
results = model("labrador.png")
# Out:
# image 1/1 c:\Users\yx084\OneDrive\Python-Modules\DL\3.PART\labrador.png: 640x640 4 persons, 1 dog, 92.1ms
# Speed: 8.0ms preprocess, 92.1ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
for result in results:
  result.show()
  result.save(filename="result.jpg")
