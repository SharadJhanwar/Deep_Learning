# %% [markdown]
# ## MAE
# ## MSE
# ## log loss

# %% [markdown]
# ## MAE

# %%
import numpy as np

# %%
y_predicted = np.array([1,1,0,0,1])
y_true = np.array([0.30,0.7,1,0,0.5])

# %%
def mae(y_true, y_predicted):
  total_error = 0
  for yt, yp in zip(y_true,y_predicted):
    total_error += abs(yt-yp)
  print("Total Error : ",total_error)
  mae = total_error/len(y_true)
  print("MAE : ",mae)
  return mae

# %%
mae(y_true,y_predicted)
# Out:
# Total Error :  2.5
# MAE :  0.5
# np.float64(0.5)

# %%
## USING Numpy

np.mean(np.abs(y_predicted-y_true))
# Out:
# np.float64(0.5)

# %% [markdown]
# ## Log loss

# %%
epsilon = 1e-15

# %%
# why y_preicted_new ? bcz see formula
# and if we do log(1-1) = log0 i.e. not defined also change 0 to nearky zero
y_predicted_new = [max(i,epsilon) for i in y_predicted]
y_predicted_new
# Out:
# [np.int64(1), np.int64(1), 1e-15, 1e-15, np.int64(1)]

# %%
y_predicted_new = [min(i,1-epsilon) for i in y_predicted]
y_predicted_new
# Out:
# [0.999999999999999,
#  0.999999999999999,
#  np.int64(0),
#  np.int64(0),
#  0.999999999999999]

# %%
y_true = np.array(y_true, dtype=np.float64)
y_predicted_new = np.array(y_predicted_new, dtype=np.float64)

# %%
logloss = -np.mean(
    y_true * np.log(y_predicted_new) +
    (1 - y_true) * np.log(1 - y_predicted_new)
)
loss
# Out:
# C:\Users\yx084\AppData\Local\Temp\ipykernel_4024\1552032547.py:2: RuntimeWarning: divide by zero encountered in log
#   y_true * np.log(y_predicted_new) +
# C:\Users\yx084\AppData\Local\Temp\ipykernel_4024\1552032547.py:2: RuntimeWarning: invalid value encountered in multiply
#   y_true * np.log(y_predicted_new) +
# np.float64(nan)

# %%
logloss
# Out:
# np.float64(nan)

# %%
def log_loss(y_true,y_predicted):
  epsilon = 1e-15
  y_predicted_new = [max(i,epsilon) for i in y_predicted]
  y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
  y_predicted_new = np.array(y_predicted_new)
  return -np.mean(y_true*np.log(y_predicted_new) + (1-y_true)*np.log(1-y_predicted_new))

# %% [markdown]
# ## MSE (EXERCISE)
