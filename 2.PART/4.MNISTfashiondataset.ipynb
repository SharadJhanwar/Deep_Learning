# %% [markdown]
# # Project
# Fashion Image Classification (From MNIST fashion dataset)

# %% [markdown]
# ## 1. Problem Understanding

# %%
import tensorflow as tf
print(f"TensorFlow version: {tf.__version__}")
# Out:
# The kernel failed to start as the Python Environment 'Python 3.13.7' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
